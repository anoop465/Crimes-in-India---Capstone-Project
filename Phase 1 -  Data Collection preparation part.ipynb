# %%
import pandas as pd

# %% [raw]
# Link -  https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_population

# %% [markdown]
# # Q.1 The population of each state.

# %%
df = pd.read_excel("Population.xlsx")

# %%
df
# Out:
#     Rank                  State or Union Territory  Population
# 0      1                             Uttar Pradesh   199812341
# 1      2                               Maharashtra   112374333
# 2      3                                     Bihar   104099452
# 3      4                               West Bengal    91276115
# 4      5                            Madhya Pradesh    72626809
# 5      6                                Tamil Nadu    72147030
# 6      7                                 Rajasthan    68548437
# 7      8                                 Karnataka    61095297
# 8      9                                   Gujarat    60439692
# 9     10                            Andhra Pradesh    49577103
# 10    11                                    Odisha    41974219
# 11    12                                 Telangana    35003674
# 12    13                                    Kerala    33406061
# 13    14                                 Jharkhand    32988134
# ...

# %% [markdown]
# # Q.2 Literacy Rate in each state

# %% [raw]
# Link - https://en.wikipedia.org/wiki/List_of_Indian_states_and_union_territories_by_literacy_rate

# %%
df1 = pd.read_excel("Literacy.xlsx")

# %%
df1
# Out:
#                   State/UT   1951   1961   1971   1981   1991   2001   2011
# 0              A&N islands   30.3  40.07  51.15  63.19  73.02  81.30  86.63
# 1           Andhra Pradesh      -  21.19  24.57  35.66  44.08  60.47  67.02
# 2        Arunachal Pradesh      -   7.13  11.29  25.55  41.59  54.34  65.38
# 3                    Assam  18.53  32.95  33.94      -  52.89  63.25  72.19
# 4                    Bihar  13.49  21.95  23.17  32.32  37.49  47.00  61.80
# 5               Chandigarh      -      -  70.43   74.8  77.81  81.94  86.05
# 6             Chhattisgarh   9.41  18.14  24.08  32.63  42.91  64.66  70.28
# 7   Dadra and Nagar Haveli      -      -  18.13   32.9  40.71  57.63  76.24
# 8            Daman and Diu      -      -      -      -   71.2  78.18  87.10
# 9                    Delhi      -  61.95  65.08  71.94  75.29  81.67  86.21
# 10                     Goa  23.48  35.41  51.96  65.71  75.51  82.01  88.70
# ...

# %% [markdown]
# # Q.3 Area of each state

# %% [raw]
# Link -	https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_area

# %%
df2 = pd.read_excel("area.xlsx")
df2
# Out:
#     Rank                    State /Union Territory  Area (km2)
# 0      1                                 Rajasthan      342239
# 1      2                            Madhya Pradesh      308252
# 2      3                               Maharashtra      307713
# 3      4                             Uttar Pradesh      240928
# 4      5                                   Gujarat      196024
# 5      6                                 Karnataka      191791
# 6      7                            Andhra Pradesh      162975
# 7      8                                    Odisha      155707
# 8      9                              Chhattisgarh      135192
# 9     10                                Tamil Nadu      130058
# 10    11                                 Telangana      112077
# 11    12                                     Bihar       94163
# 12    13                               West Bengal       88752
# 13    14                         Arunachal Pradesh       83743
# ...

# %% [markdown]
# # Q.4  Collect any other data that helps with your analysis. There is no limitation for anything.

# %% [raw]
# Link -	https://en.wikipedia.org/wiki/Rape_in_India

# %% [markdown]
# # Rape Cases

# %%
df3 = pd.read_excel("Rapecases.xlsx")
df3
# Out:
#                        State/UT  Total rape cases registered(2019)  \
# 0                Andhra Pradesh                               1086
# 1             Arunachal Pradesh                                 63
# 2                         Assam                               1773
# 3                         Bihar                                730
# 4                  Chhattisgarh                               1036
# 5                           Goa                                 72
# 6                       Gujarat                                528
# 7                       Haryana                               1480
# 8              Himachal Pradesh                                359
# 9             Jammu and Kashmir                                223
# 10                    Jharkhand                               1416
# 11                    Karnataka                                505
# 12                       Kerala                               2023
# ...
